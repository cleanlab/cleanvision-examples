# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cleanlab/cleanvision-examples/blob/main/caltech256.ipynb)

# %% [markdown]
# This notebook runs CleanVision on [Caltech-256](https://data.caltech.edu/records/nyy15-4j048) dataset.

# %%
# !pip install -U pip
# !pip install cleanvision

# %% [markdown]
# **After you install these packages, you may need to restart your notebook runtime before running the rest of this notebook.**

# %%
import tarfile
import pandas as pd

from cleanvision import Imagelab

# %% [markdown]
# ### Download and extract dataset

# %%
# !wget https://data.caltech.edu/records/nyy15-4j048/files/256_ObjectCategories.tar

# %%
file = tarfile.open('256_ObjectCategories.tar')
file.extractall()
file.close()

# %% [markdown]
# ### Run CleanVision

# %%
imagelab = Imagelab(data_path="./256_ObjectCategories")
# Out:
# Reading images from /home/sanjana/cleanvision-examples/256_ObjectCategories

# %%
imagelab.find_issues()
# Out:
# Checking for dark, light, odd_aspect_ratio, low_information, exact_duplicates, near_duplicates, blurry, grayscale images ...
#   0%|          | 0/30607 [00:00<?, ?it/s]
#   0%|          | 0/30607 [00:00<?, ?it/s]
# Issue checks completed. To see a detailed report of issues found, use imagelab.report().

# %% [markdown]
# ### Report all the issues found in the dataset

# %%
imagelab.report()
# Out:
# Issues found in order of severity in the dataset
#
# |    | issue_type       |   num_images |
# |---:|:-----------------|-------------:|
# |  0 | grayscale        |          422 |
# |  1 | odd_aspect_ratio |          208 |
# |  2 | near_duplicates  |          167 |
# |  3 | low_information  |          116 |
# |  4 | blurry           |           59 |
# |  5 | exact_duplicates |           31 |
# |  6 | dark             |           23 |
# |  7 | light            |           17 |
#
#
# Top 4 examples with grayscale issue in the dataset.
# Top 4 examples with odd_aspect_ratio issue in the dataset.
# Top 4 sets of images with near_duplicates issue
# Set: 0
# Set: 1
# Set: 2
# Set: 3
# Top 4 examples with low_information issue in the dataset.
# Top 4 examples with blurry issue in the dataset.
# Top 4 sets of images with exact_duplicates issue
# Set: 0
# Set: 1
# Set: 2
# Set: 3
# Top 4 examples with dark issue in the dataset.
# Top 4 examples with light issue in the dataset.

# %% [markdown]
# View more information about each image, such as what types of issues it exhibits and its quality score with respect to each type of issue.

# %%
imagelab.issues
# Out:
#                                                     odd_aspect_ratio_score
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.557114  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.813433
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.620000
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.740000
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.526316
# ...                                                                    ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.674699
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.749004
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.803867
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.856655
# /home/sanjana/cleanvision-examples/256_ObjectCa...                0.718876
#
#                                                     is_odd_aspect_ratio_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# ...                                                                       ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
#
#                                                     low_information_score
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.857837  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.487936
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.558810
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.776464
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.820823
# ...                                                                   ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.885462
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.860449
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.869255
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.878232
# /home/sanjana/cleanvision-examples/256_ObjectCa...               0.925517
#
#                                                     is_low_information_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# ...                                                                      ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
#
#                                                     light_score
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.735513  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.757508
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.795394
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.933221
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.964787
# ...                                                         ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.921824
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.523862
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.877246
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.611692
# /home/sanjana/cleanvision-examples/256_ObjectCa...     0.956271
#
#                                                     is_light_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# ...                                                            ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
# /home/sanjana/cleanvision-examples/256_ObjectCa...           False
#
#                                                     grayscale_score
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# ...                                                             ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
# /home/sanjana/cleanvision-examples/256_ObjectCa...                1
#
#                                                     is_grayscale_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# ...                                                                ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
# /home/sanjana/cleanvision-examples/256_ObjectCa...               False
#
#                                                     dark_score  is_dark_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.910494          False  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...    1.000000          False
# /home/sanjana/cleanvision-examples/256_ObjectCa...    1.000000          False
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.413931          False
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.774649          False
# ...                                                        ...            ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.986569          False
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.978674          False
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.901041          False
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.993031          False
# /home/sanjana/cleanvision-examples/256_ObjectCa...    0.900774          False
#
#                                                     blurry_score
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.504842  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...      1.000000
# /home/sanjana/cleanvision-examples/256_ObjectCa...      1.000000
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.537725
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.379288
# ...                                                          ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.542177
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.506221
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.494764
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.492889
# /home/sanjana/cleanvision-examples/256_ObjectCa...      0.520734
#
#                                                     is_blurry_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# ...                                                             ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
# /home/sanjana/cleanvision-examples/256_ObjectCa...            False
#
#                                                     exact_duplicates_score
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# ...                                                                    ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     1.0
#
#                                                     is_exact_duplicates_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# ...                                                                       ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                      False
#
#                                                     near_duplicates_score
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0  \
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# ...                                                                   ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
# /home/sanjana/cleanvision-examples/256_ObjectCa...                    1.0
#
#                                                     is_near_duplicates_issue
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# ...                                                                      ...
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
# /home/sanjana/cleanvision-examples/256_ObjectCa...                     False
#
# [30607 rows x 16 columns]

# %% [markdown]
# View global information about each issue, such as how many images in the dataset suffer from this issue.

# %%
imagelab.issue_summary
# Out:
#          issue_type  num_images
# 0         grayscale         422
# 1  odd_aspect_ratio         208
# 2   near_duplicates         167
# 3   low_information         116
# 4            blurry          59
# 5  exact_duplicates          31
# 6              dark          23
# 7             light          17

# %% [markdown]
# ### Analysis of issues found per class

# %% [markdown]
# Here we break down the issues within different groups of images. Since this is a classification dataset, we group images that share the same class label (but note that CleanVision can be run on any collection of images, regardless if the ML task is classification or not).

# %% [markdown]
# Add `class name` column to `imagelab.issues` dataframe

# %%
issues_df = imagelab.issues.copy()
class_column = "class name"
issues_df[class_column] = [path.split("/")[-2] for path in issues_df.index.to_list()]

# %% [markdown]
# Compute number of instances of each issue per class and also the num_images in each class

# %%
issues_per_class = issues_df.groupby('class name').agg(
    num_odd_aspect_ratio=pd.NamedAgg(column="is_odd_aspect_ratio_issue", aggfunc="sum"),
    num_low_information=pd.NamedAgg(column="is_low_information_issue", aggfunc="sum"),
    num_light=pd.NamedAgg(column="is_light_issue", aggfunc="sum"),
    num_grayscale=pd.NamedAgg(column="is_grayscale_issue", aggfunc="sum"),
    num_dark=pd.NamedAgg(column="is_dark_issue", aggfunc="sum"),
    num_blurry=pd.NamedAgg(column="is_blurry_issue", aggfunc="sum"),
    num_exact_duplicates=pd.NamedAgg(column="is_exact_duplicates_issue", aggfunc="sum"),
    num_near_duplicates=pd.NamedAgg(column="is_near_duplicates_issue", aggfunc="sum"),
    num_images=pd.NamedAgg(column="class name", aggfunc="count")
)

# %%
issues_per_class
# Out:
#                     num_odd_aspect_ratio  num_low_information  num_light
# class name
# 001.ak47                               5                    1          0  \
# 002.american-flag                      0                    0          0
# 003.backpack                           0                    0          0
# 004.baseball-bat                       0                    7          2
# 005.baseball-glove                     0                    0          0
# ...                                  ...                  ...        ...
# 253.faces-easy-101                     0                    0          0
# 254.greyhound                          0                    0          0
# 255.tennis-shoes                       0                    0          0
# 256.toad                               0                    0          0
# 257.clutter                            1                    0          0
#
#                     num_grayscale  num_dark  num_blurry  num_exact_duplicates
# class name
# 001.ak47                        1         0           0                     0  \
# 002.american-flag               0         0           0                     0
# 003.backpack                    0         0           0                     0
# 004.baseball-bat                0         0           1                     0
# 005.baseball-glove              0         0           0                     0
# ...                           ...       ...         ...                   ...
# 253.faces-easy-101              0         0           0                     0
# 254.greyhound                   0         0           0                     0
# 255.tennis-shoes                2         0           0                     0
# 256.toad                        0         0           0                     0
# 257.clutter                     0         3           2                     0
#
#                     num_near_duplicates  num_images
# class name
# 001.ak47                              0          98
# 002.american-flag                     0          97
# 003.backpack                          0         151
# 004.baseball-bat                      0         127
# 005.baseball-glove                    0         148
# ...                                 ...         ...
# 253.faces-easy-101                    0         435
# 254.greyhound                         0          95
# 255.tennis-shoes                      0         103
# 256.toad                              0         108
# 257.clutter                           0         827
#
# [257 rows x 9 columns]

# %% [markdown]
# Top classes with grayscale issue

# %%
issues_per_class.sort_values(by=['num_grayscale'], ascending=False)[['num_grayscale', 'num_images']].head()
# Out:
#                   num_grayscale  num_images
# class name
# 252.car-side-101            116         116
# 184.sheet-music              23          84
# 044.comet                    20         121
# 159.people                   16         209
# 020.brain-101                13          83

# %% [markdown]
# Top classes with near duplicates issue

# %%
issues_per_class.sort_values(by=['num_near_duplicates'], ascending=False)[['num_near_duplicates', 'num_images']].head()
# Out:
#                   num_near_duplicates  num_images
# class name
# 129.leopards-101                   80         190
# 137.mars                           17         156
# 090.gorilla                        14         212
# 232.t-shirt                        10         358
# 168.raccoon                         4         140

# %% [markdown]
# Top classes with exact duplicates issue

# %%
issues_per_class.sort_values(by=['num_exact_duplicates'], ascending=False)[['num_exact_duplicates', 'num_images']].head()
# Out:
#                   num_exact_duplicates  num_images
# class name
# 214.teepee                          13         139
# 023.bulldozer                        2         110
# 224.touring-bike                     2         110
# 043.coin                             2         124
# 137.mars                             2         156
