# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cleanlab/cleanvision-examples/blob/main/cub200.ipynb)

# %% [markdown]
# This notebook runs CleanVision on [Caltech-UCSD Birds-200-2011 (CUB-200-2011)](https://www.vision.caltech.edu/datasets/cub_200_2011/) dataset.

# %%
# !pip install -U pip
# !pip install git+https://github.com/cleanlab/cleanvision.git

# %% [markdown]
# **After you install these packages, you may need to restart your notebook runtime before running the rest of this notebook.**

# %%
import tarfile
import pandas as pd

from cleanvision.imagelab import Imagelab

# %% [markdown]
# ### Download and extract dataset

# %%
# !wget https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz

# %%
file = tarfile.open('CUB_200_2011.tgz')
file.extractall()
file.close()

# %% [markdown]
# ### Run CleanVision

# %%
imagelab = Imagelab(data_path="./CUB_200_2011/")
# Out:
# Reading images from /home/sanjana/cleanvision-examples/CUB_200_2011

# %%
imagelab.find_issues()
# Out:
# Checking for dark, light, odd_aspect_ratio, low_information, exact_duplicates, near_duplicates, blurry, grayscale images ...
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11788/11788 [00:04<00:00, 2374.02it/s]
# Issue checks completed. To see a detailed report of issues found, use imagelab.report().

# %% [markdown]
# ### Report all the issues found in the dataset

# %%
imagelab.report()
# Out:
# Issues found in order of severity in the dataset
#
# |    | issue_type       |   num_images |
# |---:|:-----------------|-------------:|
# |  0 | blurry           |           15 |
# |  1 | near_duplicates  |           10 |
# |  2 | grayscale        |            8 |
# |  3 | low_information  |            3 |
# |  4 | exact_duplicates |            2 |
# |  5 | light            |            1 |
# |  6 | odd_aspect_ratio |            1 |
#
#
# Top 4 examples with blurry issue in the dataset.
# Top 4 sets of images with near_duplicates issue
# Set: 0
# Set: 1
# Set: 2
# Set: 3
# Top 4 examples with grayscale issue in the dataset.
# Found 3 examples with low_information issue in the dataset.
# Found 1 set of images with exact_duplicates issue in the dataset.
# Set: 0
# Found 1 example with light issue in the dataset.
# Found 1 example with odd_aspect_ratio issue in the dataset.

# %% [markdown]
# View more information about each image, such as what types of issues it exhibits and its quality score with respect to each type of issue.

# %%
imagelab.issues
# Out:
#                                                     odd_aspect_ratio_score  \
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.696875
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.694000
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.750000
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.670000
# /home/sanjana/cleanvision-examples/CUB_200_2011...                1.000000
# ...                                                                    ...
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.666000
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.722000
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.714000
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.800000
# /home/sanjana/cleanvision-examples/CUB_200_2011...                0.666000
#
# ...

# %% [markdown]
# View global information about each issue, such as how many images in the dataset suffer from this issue.

# %%
imagelab.issue_summary
# Out:
#          issue_type num_images
# 0            blurry         15
# 1   near_duplicates         10
# 2         grayscale          8
# 3   low_information          3
# 4  exact_duplicates          2
# 5             light          1
# 6  odd_aspect_ratio          1
# 7              dark          0
